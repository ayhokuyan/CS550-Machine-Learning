# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import backend.ann as nn 
import backend.layers as lyr
import backend.activations as activ
import backend.optimizers as optim
import backend.losses as losses
import backend.initializers as init

# %%
train1 = pd.read_csv('train1.txt', delimiter='\t', names=['x','y'])
train1.reset_index(drop=True, inplace=True)
train1 = train1.to_numpy()
print(train1.shape)
train1x = train1[:,0,np.newaxis]
train1y = train1[:,1,np.newaxis]
print(train1x.shape, train1y.shape)

test1 = pd.read_csv('test1.txt', delimiter='\t', names=['x','y'])
test1.reset_index(drop=True, inplace=True)
test1 = test1.to_numpy()
print(test1.shape)
test1x = test1[:,0,np.newaxis]
test1y = test1[:,1,np.newaxis]
print(test1x.shape, test1y.shape)

#normalize
train1xNor = (train1x - np.mean(train1x))/np.std(train1x)
train1yNor = (train1y - np.mean(train1y))/np.std(train1y)
test1xNor = (test1x - np.mean(train1x))/np.std(train1x)
test1yNor = (test1y - np.mean(train1y))/np.std(train1y)
# Out:
# (60, 2)
# (60, 1) (60, 1)
# (41, 2)
# (41, 1) (41, 1)

# %%
model = nn.ANNRegressor()
layers = []
layers.append(lyr.Dense(train1xNor.shape[1], 1, activation=activ.Linear(), 
                        kernel_initializer=init.RandomUniform(minval=-0.005, maxval=0.005),
                         bias_initializer=init.RandomUniform(minval=-0.005, maxval=0.005)))

model(layers)

print(model)

opt = optim.Momentum(lr = 0.0005, momentum = 0.2)
loss = losses.MSE()
metrics = ['train_loss']

model.compile(optimizer=opt, loss=loss, metrics=metrics)

hist = model.train(train1xNor, train1yNor, epochs=10000, batch_size=15, verbose=False)
plt.plot(hist['train_loss'])
plt.show()

plt.scatter(train1xNor, train1yNor)
result_x_train = np.linspace(np.min(train1xNor), np.max(train1xNor), 100)[:,np.newaxis]
result_y_train = model.forward(result_x_train)
plt.plot(result_x_train, result_y_train, color='red')
plt.legend(['Regressed','Ground Truth'])
plt.title('Training Set 1 - No Hidden Units')
plt.show()

result_y = model.forward(train1xNor)
print('mean', np.mean((result_y - train1yNor)**2))
print('std', np.std((result_y - train1yNor)**2))
# Out:
# Layer 0: Input Dim: 1, Number of Neurons: 1 Activation: linear
# mean 0.5138974543300978
# std 0.4406987486720742

# %%
model1 = nn.ANNRegressor()
layers = []
layers.append(lyr.Dense(train1xNor.shape[1], 2, activation=activ.Sigmoid(), 
                        kernel_initializer=init.GlorotNormal(seed=1),
                         bias_initializer=init.Zeros()))
layers.append(lyr.Dense(2, 1, activation=activ.Linear(),
                        kernel_initializer=init.GlorotNormal(seed=1),
                        bias_initializer=init.Zeros()))
model1(layers)

print(model1)

opt = optim.SGD(lr = 0.001)
loss = losses.MSE()
metrics = ['train_loss']

model1.compile(optimizer=opt, loss=loss, metrics=metrics)

hist = model1.train(train1xNor, train1yNor, epochs=20000, batch_size=15, verbose=False)

plt.scatter(train1xNor, train1yNor)
result_x_train = np.linspace(np.min(train1xNor), np.max(train1xNor), 100)[:,np.newaxis]
result_y_train = model1.forward(result_x_train)
plt.plot(result_x_train, result_y_train, color='red')
plt.legend(['Regressed','Ground Truth'])
plt.title('Training Set 1 - 2 Hidden Units')
plt.show()

result_y = model1.forward(train1xNor)
print('mean', np.mean((result_y - train1yNor)**2))
print('std', np.std((result_y - train1yNor)**2))
# Out:
# Layer 0: Input Dim: 1, Number of Neurons: 2 Activation: sigmoid
# Layer 1: Input Dim: 2, Number of Neurons: 1 Activation: linear
# mean 0.17931648338406017
# std 0.20483548399973472

# %%
model2 = nn.ANNRegressor()
layers = []
layers.append(lyr.Dense(train1xNor.shape[1], 4, activation=activ.Tanh(), 
                        kernel_initializer=init.GlorotNormal(seed=1),
                         bias_initializer=init.Zeros()))
layers.append(lyr.Dense(4, 1, activation=activ.Linear(),
                        kernel_initializer=init.GlorotNormal(seed=1),
                        bias_initializer=init.Zeros()))
model2(layers)

print(model2)

opt = optim.SGD(lr = 0.001)
loss = losses.MSE()
metrics = ['train_loss']

model2.compile(optimizer=opt, loss=loss, metrics=metrics)

hist = model2.train(train1xNor, train1yNor, epochs=5000, batch_size=1, verbose=False)

plt.scatter(train1xNor, train1yNor)
result_x_train = np.linspace(np.min(train1xNor), np.max(train1xNor), 100)[:,np.newaxis]
result_y_train = model2.forward(result_x_train)
plt.plot(result_x_train, result_y_train, color='red')
plt.legend(['Regressed','Ground Truth'])
plt.title('Training Set 1 - 4 Hidden Units')
plt.show()

result_y = model2.forward(train1xNor)
print('mean', np.mean((result_y - train1yNor)**2))
print('std', np.std((result_y - train1yNor)**2))
# Out:
# Layer 0: Input Dim: 1, Number of Neurons: 4 Activation: tanh
# Layer 1: Input Dim: 4, Number of Neurons: 1 Activation: linear
# mean 0.15074000274518318
# std 0.19711512281358837

# %%
model3 = nn.ANNRegressor()
layers = []
layers.append(lyr.Dense(train1xNor.shape[1], 8, activation=activ.Tanh(), 
                        kernel_initializer=init.GlorotNormal(seed=1),
                         bias_initializer=init.Zeros()))
layers.append(lyr.Dense(8, 1, activation=activ.Linear(),
                        kernel_initializer=init.GlorotNormal(seed=1),
                        bias_initializer=init.Zeros()))
model3(layers)

print(model3)

opt = optim.Adam(lr = 0.001)
loss = losses.MSE()
metrics = ['train_loss']

model3.compile(optimizer=opt, loss=loss, metrics=metrics)

hist = model3.train(train1xNor, train1yNor, epochs=10000, batch_size=1, verbose=False)

plt.scatter(train1xNor, train1yNor)
result_x_train = np.linspace(np.min(train1xNor), np.max(train1xNor), 100)[:,np.newaxis]
result_y_train = model3.forward(result_x_train)
plt.plot(result_x_train, result_y_train, color='red')
plt.legend(['Regressed','Ground Truth'])
plt.title('Training Set 1 - 8 Hidden Units')
plt.show()

result_y = model3.forward(train1xNor)
print('mean', np.mean((result_y - train1yNor)**2))
print('std', np.std((result_y - train1yNor)**2))
# Out:
# Layer 0: Input Dim: 1, Number of Neurons: 8 Activation: tanh
# Layer 1: Input Dim: 8, Number of Neurons: 1 Activation: linear

# %%
model4 = nn.ANNRegressor()
layers = []
layers.append(lyr.Dense(train1xNor.shape[1], 16, activation=activ.Tanh(), 
                        kernel_initializer=init.GlorotNormal(seed=1),
                         bias_initializer=init.Zeros()))
layers.append(lyr.Dense(16, 1, activation=activ.Linear(),
                        kernel_initializer=init.GlorotNormal(seed=1),
                        bias_initializer=init.Zeros()))
model4(layers)

print(model4)

opt = optim.Adam(lr = 0.01)
loss = losses.MSE()
metrics = ['train_loss']

model4.compile(optimizer=opt, loss=loss, metrics=metrics)

hist = model4.train(train1xNor, train1yNor, epochs=10000, batch_size=1, verbose=False)


plt.scatter(train1xNor, train1yNor)
result_x_train = np.linspace(np.min(train1xNor), np.max(train1xNor), 100)[:,np.newaxis]
result_y_train = model4.forward(result_x_train)
plt.plot(result_x_train, result_y_train, color='red')
plt.legend(['Regressed','Ground Truth'])
plt.title('Training Set 1 - 16 Hidden Units') 
plt.show()

result_y = model4.forward(train1xNor)
print('mean', np.mean((result_y - train1yNor)**2))
print('std', np.std((result_y - train1yNor)**2))
