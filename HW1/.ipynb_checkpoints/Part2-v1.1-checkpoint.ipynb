# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

# %%
#load train_data
#set current working directory
cwd = os.getcwd()
#load train data as csv
train_data = pd.read_csv(os.path.join(cwd, 'train_data.txt'), sep=' ', header=None)
train_data.reset_index(drop=True, inplace=True)
train_data = train_data.to_numpy()[:,:-2]

#load test data as csv
test_data = pd.read_csv(os.path.join(cwd, 'test_data.txt'), sep=' ', header=None)
test_data.reset_index(drop=True, inplace=True)
test_data = test_data.to_numpy()[:,:-2]

#convert to features and labels
print(train_data.shape)
print(test_data.shape)

numFeatures = train_data.shape[1]
train_features = train_data[:,:numFeatures-2]
train_labels = train_data[:,numFeatures-1]
test_features = test_data[:,:numFeatures-2]
test_labels = test_data[:,numFeatures-1]

print(train_features.shape)
print(train_labels.shape)

#load feature names 
featNames = pd.read_csv(os.path.join(cwd, 'thy_cost.txt'), sep=':', header=None)
#featNames.reset_index(drop=True, inplace=True)
featNames = featNames.to_numpy()[:,0]
print(featNames, featNames.shape)
featNames = np.append(featNames, '-')
# Out:
# (3772, 22)
# (3428, 22)
# (3772, 20)
# (3772,)
# ['age' 'sex' 'on_thyroxine' 'query_on_thyroxine'
#  'on_antithyroid_medication' 'sick' 'pregnant' 'thyroid_surgery'
#  'I131_treatment' 'query_hypothyroid' 'query_hyperthyroid' 'lithium'
#  'goitre' 'tumor' 'hypopituitary' 'psych' 'TSH' 'T3' 'TT4' 'T4U'] (20,)

# %%
def gini(nodeLabels):
    labels, counts = np.unique(nodeLabels, return_counts=True)
    gini = 0
    all_counts = np.sum(counts)
    for i in range(len(labels)):
        gini += (counts[i]/all_counts)**2 
    gini_imp = (1 - gini)
    return gini_imp   

def entropy(nodeLabels):
    labels, counts = np.unique(nodeLabels, return_counts=True)
    entropy = 0
    all_counts = np.sum(counts)
    for i in range(len(labels)):
        entropy += (counts[i]/all_counts)*np.log(counts[i]/all_counts)
    return entropy   

def calcImpurity(nodeLabels, impurity):
    if(choice == 'gini'):
        return gini(nodeLabels)
    elif(choice == 'entropy'):
        return entropy(nodeLabels)
    else:
        raise Exception("Invalid choice of Impurity: " + impurity)
        
def calcSplitImpurity(labels, val, impurity):
    left_split = labels[feature <= val]
    p_left = len(left_split)/len(labels)
    right_split = labels[feature > val]
    return p_left * calcImpurity(left_split, choice) + (1-p_left) * calcImpurity(right_split, choice)


def bestSplitofFeature(feature, labels, impurity):
    best_wimp = np.inf
    threshold = np.inf
    for val in feature:
        weighted_impurity = calcSplitImpurity(labels, val, impurity)
        if(weighted_impurity <= best_wimp):
            best_wimp = weighted_impurity;
            threshold = val
    return best_wimp, threshold

def bestSplit(features, labels, impurity='gini'):
    featureIndex = 20
    best_wimp = np.inf
    threshold = np.inf
    
    for i in range(features.shape[1]):
        feature_oi = features[:,i]
        wimp, thr = bestSplitofFeature(feature_oi, labels, impurity)
        if(wimp < best_wimp):
            best_wimp = wimp
            featureIndex = i
            threshold = thr
    
    left_features = features[features[:,featureIndex] <= threshold]
    left_labels = labels[features[:,featureIndex] <= threshold]
    
    right_features = features[features[:,featureIndex] > threshold]
    right_labels = labels[features[:,featureIndex] > threshold]
    
    return threshold, featureIndex, left_features, left_labels, right_features, right_labels

class Node():
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels 
        self.children = []
        self.split = 0.5
        self.split_index = 20
        
    def isPure(self):
        return np.min(self.labels) == np.max(self.labels)
    
def create_tree(node, impurity='gini'):
    if(node.isPure()):
        return        
    else:
        split_val, split_feat_index, left_features, left_labels, right_features, right_labels = bestSplit(node.features, node.labels, impurity)
        node.split = split_val
        node.split_index = split_feat_index
                
        left_child = Node(left_features, left_labels)
        right_child = Node(right_features, right_labels)
        node.children.append(left_child)
        node.children.append(right_child)
        
        print(featNames[node.split_index])
        
        create_tree(left_child)
        create_tree(right_child)

# %%
bestSplitofFeature(np.asarray([1,2,3,4,5,6,7]), np.asarray([0,0,0,1,1,1,1]))
# Out:
# (0.0, 3)

# %%
root = Node(train_features,train_labels)
create_tree(root)
# Out:
# TSH
# TT4
# thyroid_surgery
# T4U
# TSH
# age
# TSH
# T4U
# age
# on_thyroxine
# TT4
# thyroid_surgery
# T4U
# T3
# TSH
# TT4
# T4U
# I131_treatment
# age
# T3
# age
# age
# TT4
# TT4
# TSH
# TT4
# T3

# %%
def formatNode(node, names):
    lbs, cts = np.unique(node.labels, return_counts=True)
    countTemp = '['
    for lb,ct in zip(lbs,cts):
        countTemp += str(int(lb)) + ':' + str(ct) + ', '
    countTemp = countTemp[:-2] + ']'
    temp = names[node.split_index] + '\n' + countTemp    
    return temp

def traverse(root,names):
    current_level = [root]
    while current_level:
        temp = ''
        i=0
        for node in current_level:
            i += 1
            lbs, cts = np.unique(node.labels, return_counts=True)
            temp += formatNode(node,names)
            if(i%2==0):
                temp += '    '
        print(temp)
        next_level = list()
        for n in current_level:
            if not n.isPure():
                next_level.append(n.children[0])
                next_level.append(n.children[1])
                
        current_level = next_level
traverse(root, featNames)
# Out:
# TSH
# [1:93, 2:191, 3:3488]
# -
# [3:3409]TT4
# [1:93, 2:191, 3:79]
# thyroid_surgery
# [1:79, 2:3, 3:5]on_thyroxine
# [1:14, 2:188, 3:74]
# T4U
# [1:79, 2:3, 3:2]-
# [3:3]    TT4
# [1:12, 2:188, 3:21]TSH
# [1:2, 3:53]
# TSH
# [1:1, 2:1, 3:2]TSH
# [1:78, 2:2]    thyroid_surgery
# [1:12, 2:188, 3:11]-
# [3:10]    TT4
# [1:1, 3:53]-
# [1:1]
# -
# [3:2]age
# [1:1, 2:1]    T4U
# [1:5, 2:2]-
# [1:73]    T4U
# [1:10, 2:188, 3:4]TT4
# [1:2, 3:7]    T3
# [1:1, 3:2]-
# [3:51]
# -
# [1:1]-
# [2:1]    age
# [1:1, 2:2]-
# [1:4]    T3
# [1:6, 2:182, 3:4]TT4
# [1:4, 2:6]    -
# [1:2]-
# [3:7]    -
# [3:2]-
# [1:1]
# -
# [1:1]-
# [2:2]    TSH
# [1:6, 2:181, 3:2]age
# [2:1, 3:2]    -
# [1:4]-
# [2:6]
# TT4
# [1:4, 2:180, 3:2]age
# [1:2, 2:1]    -
# [2:1]-
# [3:2]
# T4U
# [1:4, 2:31, 3:2]-
# [2:149]    -
# [1:2]-
# [2:1]
# I131_treatment
# [1:1, 2:31]T3
# [1:3, 3:2]
# -
# [2:30]age
# [1:1, 2:1]    -
# [1:3]-
# [3:2]
# -
# [2:1]-
# [1:1]

# %%
COUNT = [10]
# Function to print binary tree in 2D  
# It does reverse inorder traversal  
def print2DUtil(root, space) : 
  
    # Base case  
    if (root.isPure()) :
        return
  
    # Increase distance between levels  
    space += COUNT[0] 
  
    # Process right child first  
    print2DUtil(root.children[0], space)  
  
    # Print current node after space  
    # count  
    print()  
    for i in range(COUNT[0], space): 
        print(end = " ")  
    print(featNames[root.split_index])  
  
    # Process left child  
    print2DUtil(root.children[1], space)  
  
# Wrapper over print2DUtil()  
def print2D(root) : 
      
    # space=[0] 
    # Pass initial space count as 0  
    print2DUtil(root, 0) 
    
print2D(root)
# Out:
# TSH
#
#                                         TSH
#
#                                                   age
#
#                               T4U
#
#                                                             age
#
#                                                   T4U
#
#                                         TSH
#
#                     thyroid_surgery
#
#           TT4
#
#                                                                                                     I131_treatment
#
#                                                                                                               age
#
#                                                                                           T4U
#
#                                                                                                     T3
#
#                                                                                 TT4
#
#                                                                       TSH
#
#                                                                                 age
#
#                                                             T3
#
#                                                                       age
#
#                                                   T4U
#
#                                                             TT4
#
#                                         thyroid_surgery
#
#                                                   TT4
#
#                               TT4
#
#                     on_thyroxine
#
#                                                   T3
#
#                                         TT4
#
#                               TSH

# %%
def predict(node, inp):
    if(node.isPure()):
        return node.labels[0]
    else:
        if(inp[node.split_index] <= node.split):
            pred = predict(node.children[0], inp)
        else:
            pred = predict(node.children[1], inp)
        return pred
def pred_samples(root, inp):
    res = []
    for i in range(inp.shape[0]):
        res.append(predict(root, inp[i,:]))
    return np.asarray(res)

# %%
def traintestresults(root, train_features, train_labels, test_features, test_labels):
    #TRAINING ACCURACIES
    train_pred = pred_samples(root, train_features)
    #print(train_pred.shape, train_pred.min(), train_pred.max())
    print('Training Accuracy: %.3f%%' % (np.sum(train_pred==train_labels)
          /train_pred.shape[0]*100))
    numSamples = np.zeros(3)
    truePreds =  np.zeros(3)
    for sample, result in zip(train_labels, train_pred):
        numSamples[int(result)-1] += 1
        if(sample == result):
            truePreds[int(result)-1] += 1
    classAccs = truePreds/numSamples*100
    print('Class-Based Accuracies:')
    for i in range(3):
        print('Accuracy of Class %d: %.3f%%' % (i+1,classAccs[i]))
    cm = confusion_matrix(train_labels, train_pred, labels=[1,2,3])
    cm_display = ConfusionMatrixDisplay(cm, display_labels=[1,2,3]).plot()
    plt.title('Confusion Matrix for Training Data')
    plt.show()
    
    #TEST ACCURACIES
    test_pred = pred_samples(root, test_features)
    #print(test_pred.shape, test_pred.min(), test_pred.max())
    print('Test Accuracy: %.3f%%' % (np.sum(test_pred==test_labels)
          /test_pred.shape[0]*100))
    numSamples = np.zeros(3)
    truePreds =  np.zeros(3)
    for sample, result in zip(test_labels, test_pred):
        numSamples[int(result)-1] += 1
        if(sample == result):
            truePreds[int(result)-1] += 1
    classAccs = truePreds/numSamples*100
    print('Class-Based Accuracies:')
    for i in range(3):
        print('Accuracy of Class %d: %.3f%%' % (i+1,classAccs[i]))
        
    cm = confusion_matrix(test_labels, test_pred, labels=[1,2,3])
    cm_display = ConfusionMatrixDisplay(cm, display_labels=[1,2,3]).plot()
    plt.title('Confusion Matrix for Test Data')
    plt.show()
traintestresults(root, train_features, train_labels, test_features, test_labels)
# Out:
# Training Accuracy: 100.000%
# Class-Based Accuracies:
# Accuracy of Class 1: 100.000%
# Accuracy of Class 2: 100.000%
# Accuracy of Class 3: 100.000%
# Test Accuracy: 98.891%
# Class-Based Accuracies:
# Accuracy of Class 1: 81.579%
# Accuracy of Class 2: 91.579%
# Accuracy of Class 3: 99.747%
